# %% [markdown]
# # MODULE: data_parameters
#
# ## Description
# Global parameters for data types and precision
# Converted from: `data_parameters.f90`
#
# ## Original Code Owner
# DWD, Ulrich Schaettler
#
# ## History
# - Version 1.1 (1998/03/11) - Initial release
#
# ## Role
# Base infrastructure module that defines precision kinds and global numeric parameters.
# This is the **root module** - nearly everything else depends on it.
#
# ## Defines
# - `ireals` - KIND for real numbers (float64)
# - `iintegers` - KIND for integers (int32)
# - Generic numeric tolerances and constants
#
# ## Dependencies
# - Uses: **(none)** - This is the base module
# - Used by: All other modules

# %%
import numpy as np

print("FLake Model - MODULE: data_parameters")
print("=" * 70)

# %% [markdown]
# ## Precision Kinds
#
# Fortran KIND parameters mapped to NumPy dtypes.
# These define the precision for all numerical calculations in FLake.

# %%
# ireals: Fortran SELECTED_REAL_KIND(12,200)
# - 12 significant digits
# - Exponent range of 200
# - Corresponds to 8-byte real (double precision)
ireals = np.float64

# iintegers: Fortran KIND(1)
# - Default integer kind
# - Corresponds to 4-byte integer
iintegers = np.int32

# %% [markdown]
# ## Verification
#
# Display data type information to confirm correct precision.

# %%
print("Data Parameters Module Loaded")
print("-" * 70)
print(f"ireals    : {ireals} (64-bit floating point)")
print(f"iintegers : {iintegers} (32-bit integer)")
print("")
print(f"Float range    : [{np.finfo(ireals).min:.2e}, {np.finfo(ireals).max:.2e}]")
print(f"Float precision: {np.finfo(ireals).precision} decimal digits")
print(f"Integer range  : [{np.iinfo(iintegers).min}, {np.iinfo(iintegers).max}]")
print("=" * 70)
print("✅ data_parameters module ready")

# %% [markdown]
# ## Module Status
#
# ✅ **Module complete and ready for use**
#
# This module can now be imported by other FLake modules:
# ```python
# from data_parameters import ireals, iintegers
# ```
